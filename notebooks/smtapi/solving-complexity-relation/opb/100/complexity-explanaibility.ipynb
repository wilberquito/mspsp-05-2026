# %% [markdown]
# # Analysis of complexity of MSPSP with results from PseudoBoolean solver

# %%
# !pwd
# Out:
# /Users/wilberquito/repos/mspsp/notebooks/smtapi/complexity/opb/1000

# %%
import pandas as pd
import os
import numpy as np

working_dir = "/Users/wilberquito/repos/mspsp"
os.chdir(working_dir)

# !pwd
# Out:
# /Users/wilberquito/repos/mspsp

# %%
result_opb_csv = "data/smtapi/wandb/smtapi-MSPSP__ma_grups@f=opb__s=exactpb__i=i1=1,i2=0,i3=0,i4=0__pb_like=0.csv"
df_opb = pd.read_csv(result_opb_csv)
df_opb.shape
# Out:
# (1142, 22)

# %%
df_opb.head(2)
# Out:
#    Unnamed: 0            name formalism  implied_1  implied_2  implied_3  \
# 0           0   fresh-disco-1       opb        1.0        0.0        0.0
# 1           1  lyric-shadow-2       opb        1.0        0.0        0.0
#
#    implied_4                                      inline_config  \
# 0        0.0  f=opb__s=exactpb__i=i1=1,i2=0,i3=0,i4=0__pb_li...
# 1        0.0  f=opb__s=exactpb__i=i1=1,i2=0,i3=0,i4=0__pb_li...
#
#                                       mspsp_instance  pb_like  ...  \
# 0  ./modules/rcpsp-instances/MSPSP/set-1a/inst_se...      0.0  ...
# 1  ./modules/rcpsp-instances/MSPSP/set-1a/inst_se...      0.0  ...
#
#   encoder.real_time  encoder.sys_time  encoder.user_time  makespan  \
# 0              0.08              0.03               0.04      61.0
# 1              0.08              0.02               0.05      66.0
#
#                                                model  slurm.timeout  \
# 0  v S_0:0; S_1:45; S_2:0; S_3:0; S_4:9; S_5:12; ...          False
# 1  v S_0:0; S_1:10; S_2:7; S_3:0; S_4:11; S_5:28;...          False
#
#   solution_status  solver.real_time solver.sys_time  solver.user_time
# 0   OPTIMUM_FOUND             15.38            0.01             15.29
# 1   OPTIMUM_FOUND              7.26            0.02              7.20
#
# [2 rows x 22 columns]

# %%
hardness_instances_csv = "data/smtapi/analysis/instances/mspsp_stats.csv"
df_hardness = pd.read_csv(hardness_instances_csv)
df_hardness.shape
# Out:
# (1142, 10)

# %%
df_hardness.head(2)
# Out:
#    family  n_activities  n_skills  n_resources  n_precedences  skill_factor  \
# 0  set-1a            22         4           10             31           0.5
# 1  set-1a            22         4           10             31           0.5
#
#    modified_resource_strength  network_complexity  network_density  \
# 0                       0.125            1.409091         0.134199
# 1                       0.125            1.409091         0.134199
#
#                                       mspsp_instance
# 0  ./modules/rcpsp-instances/MSPSP/set-1a/inst_se...
# 1  ./modules/rcpsp-instances/MSPSP/set-1a/inst_se...

# %%
# Merge dataframes on `mspsp_instance`
df_merged = pd.merge(df_opb, df_hardness, on="mspsp_instance", how="inner")
df_merged.shape
# Out:
# (1142, 31)

# %%
df_merged.columns
# Out:
# Index(['Unnamed: 0', 'name', 'formalism', 'implied_1', 'implied_2',
#        'implied_3', 'implied_4', 'inline_config', 'mspsp_instance', 'pb_like',
#        'solver', 'solving_timeout_s', 'encoder.real_time', 'encoder.sys_time',
#        'encoder.user_time', 'makespan', 'model', 'slurm.timeout',
#        'solution_status', 'solver.real_time', 'solver.sys_time',
#        'solver.user_time', 'family', 'n_activities', 'n_skills', 'n_resources',
#        'n_precedences', 'skill_factor', 'modified_resource_strength',
#        'network_complexity', 'network_density'],
#       dtype='object')

# %%
# Generate bitmask for implied
def add_implied_column(df: pd.DataFrame, check: bool) -> pd.DataFrame:
    # Creamos un ID único para la configuración de implied constraints

    impl_cols = [c for c in df.columns if "implied_" in c]
    df["implied_bitmask"] = df[impl_cols].apply(
        lambda x: "".join(["1" if val else "0" for val in x]), axis=1
    )

    if check:
        config_count = df["implied_bitmask"].value_counts()
        s = config_count.iloc[0]
        diff_n_count = 0
        logger: list[str] = list()

        for i, c in enumerate(config_count):
            if c != s:
                diff_n_count += 1
                logger.append(config_count.index[i])

        if diff_n_count > 0:
            print(
                f"WARNING: Configuration count mismatch: {diff_n_count} configurations have a different count than the first one"
            )
            print("Mismatched configurations:", logger)

    return df


def add_logarithmic_time(df: pd.DataFrame) -> pd.DataFrame:
    df["solver.log_real_time"] = df["solver.real_time"].apply(
        lambda x: np.log10(x + 1e-6)
    )
    return df


df_merged = add_implied_column(df_merged, check=True)
df_merged = add_logarithmic_time(df_merged)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Prepare data
df_merged["factor_mrs_nc"] = (
    df_merged["modified_resource_strength"] * df_merged["network_complexity"]
)
df_merged["factor_mrs_nd"] = (
    df_merged["modified_resource_strength"] * df_merged["network_density"]
)
y_features = [
    "network_complexity",
    "network_density",
    "modified_resource_strength",
    "factor_mrs_nc",
    "factor_mrs_nd",
]
x_features = ["solver.real_time", "solver.log_real_time"]

fig, axes = plt.subplots(len(y_features), len(x_features), figsize=(16, 15))
timeout_val = 600
timeout_log = np.log10(timeout_val)

for i, y_var in enumerate(y_features):
    for j, x_var in enumerate(x_features):
        ax = axes[i, j]

        # Plot data
        sns.scatterplot(
            data=df_merged,
            x=x_var,
            y=y_var,
            hue="implied_bitmask",
            palette="Set2",
            ax=ax,
        )

        # Handle Diagonal Line
        x_min, x_max = df_merged[x_var].min(), df_merged[x_var].max()
        y_min, y_max = df_merged[y_var].min(), df_merged[y_var].max()
        ax.plot([x_min, x_max], [y_min, y_max], color="red", linestyle="--", alpha=0.6)

        # 1. Get current numeric ticks
        current_ticks = list(ax.get_xticks())

        if x_var == "solver.log_real_time":
            # 2. Add timeout in log scale, then sort numerically
            all_ticks = sorted(current_ticks + [timeout_log])

            # 3. Create labels by mapping log values back to real seconds (10^t)
            labels = []
            for t in all_ticks:
                real_seconds = 10**t
                if np.isclose(t, timeout_log):
                    labels.append("t.o.")
                else:
                    # Show simplified seconds for cleaner look
                    labels.append(f"{real_seconds:.1f}s")
        else:
            # Linear scale logic
            all_ticks = sorted(current_ticks + [timeout_val])
            labels = []
            for t in all_ticks:
                if np.isclose(t, timeout_val):
                    labels.append("t.o.")
                else:
                    # Show simplified seconds for cleaner look
                    labels.append(f"{t:.1f}s")

        ax.set_xticks(all_ticks)
        ax.set_xticklabels(labels, rotation=45)
        # ------------------------

        ax.set_title(f"{y_var} vs {x_var}")

        # Manage legends - only show one on the top right
        if i == 0 and j == 1:
            ax.legend(
                title="Implied Constraints", bbox_to_anchor=(1.05, 1), loc="upper left"
            )
        else:
            if ax.get_legend():
                ax.get_legend().remove()

plt.tight_layout()
plt.show()

# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr
from sklearn.feature_selection import mutual_info_regression

# List of variables to test against log_real_time
variables = [
    "network_complexity",
    "network_density",
    "modified_resource_strength",
    "skill_factor",
    "factor_mrs_nc",
    "factor_mrs_nd",
]
target = "solver.real_time"

results = []

for var in variables:
    # Remove NaN values for the calculation
    temp_df = df_merged[[var, target]].dropna()

    # 1. Pearson
    p_corr, _ = pearsonr(temp_df[var], temp_df[target])

    # 2. Spearman
    s_corr, _ = spearmanr(temp_df[var], temp_df[target])

    # 3. Mutual Information (requires reshaping)
    mi = mutual_info_regression(temp_df[[var]], temp_df[target], random_state=42)[0]

    results.append(
        {
            "Variable": var,
            "Pearson (Linear)": round(p_corr, 3),
            "Spearman (Monotonic)": round(s_corr, 3),
            "Mutual Info": round(mi, 3),
        }
    )

# Display as a Table
stats_df = pd.DataFrame(results)
stats_df
# Out:
#                      Variable  Pearson (Linear)  Spearman (Monotonic)  \
# 0          network_complexity            -0.050                -0.025
# 1             network_density            -0.426                -0.463
# 2  modified_resource_strength            -0.372                -0.325
# 3                skill_factor             0.273                 0.266
# 4               factor_mrs_nc            -0.371                -0.334
# 5               factor_mrs_nd            -0.447                -0.423
#
#    Mutual Info
# 0        0.344
# 1        0.331
# 2        0.308
# 3        0.143
# 4        0.292
# 5        0.290

# %% [markdown]
# This study shows that the complexity of MSPSP instances, as measured by various features, has a hight correlation with the PseudoBoolean solver's runtime.
# There is an important linear and / or monotonic inverse correlation between the `network_density`, the `modified_resource_strength` given by the Pearson correlation coefficient but
# the `mutual information` shows that the `network_density` is the most informative feature to predict the runtime of the PseudoBoolean solver.
#
# On the other hand `network_complexity` has null linear nor monotonic correlation with the runtime of the PseudoBoolean solver but strong mutual information, which means that it has a non-linear non-monotonic relationship with the runtime of the PseudoBoolean solver. Showing the difficulty of predicting the runtime of the PseudoBoolean solver with a simple linear or monotonic model or the unexpected time solving behavior of the PseudoBoolean solver on some instances.
